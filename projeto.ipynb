# %% [markdown]
# # Projeto
# Projeto desenvolvido durante o curso de: "Conhecendo a biblioteca Pandas" como parte da formação em Data Science.
# O banco de dados e as demandas estão organizadas na plataforma Trello.(https://trello.com/b/sLsEMlNc/pandas-conhecendo-a-bilioteca)

# %% [markdown]
# # Importando bilbiotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly as plt

# %% [markdown]
# # Demandas time ML

# %% [markdown]
# # Importando e explorando banco de dados

# %%
dados = pd.read_csv('aluguel.csv', sep=';')
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
# últimas linhas
dados.tail()
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Características gerais da BD

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
# obter os tipos de dados contidos no BD
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
dados[['Quartos', 'Valor']]
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# # Análise exploratória dos dados

# %% [markdown]
# Qual o valor médio de aluguel por tipo de imóvel?

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
# para responder a pegunta precisamos das colunas Tipo e Valor para calcular a média
dados['Valor'].mean()
# Out:
# 12952.659715265761

# %%
# média dos dados numericos agrupados por tipo de imóvel
dados.groupby('Tipo').mean(numeric_only=True)
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %% [markdown]
# Média dos valores do aluguel por tipo de imóvel

# %%
df_preco_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values(by='Valor', ascending=False)
df_preco_tipo
# Out:
#                                      Valor
# Tipo
# Prédio Inteiro               498637.239203
# Indústria                    120000.000000
# Galpão/Depósito/Armazém       53407.062600
# Terreno Padrão                32567.714286
# Hotel                         25000.000000
# Loteamento/Condomínio         22000.000000
# Conjunto Comercial/Sala       14715.045521
# Casa Comercial                14478.264151
# Loja/Salão                    13769.646770
# Sítio                         12499.000000
# Casa de Condomínio            11952.061245
# Loja Shopping/ Ct Comercial    8126.178862
# Casa                           6793.454922
# Chácara                        4900.000000
# Apartamento                    4744.614648
# Flat                           4546.189076
# Loft                           2557.882353
# Studio                         2400.000000
# Box/Garagem                    1899.756098
# Casa de Vila                   1574.369478
# Pousada/Chalé                  1480.000000
# ...

# %%
df_preco_tipo.plot(kind='barh', figsize=(14,10), color = 'blue')
# como podemos observar os valores são muito distinto pois está agrupado os comerciais e residenciais
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# Removendo os imóveis comerciais

# %%
# como o interesse é nos residenciais vamos remover os do tipo comerciais
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala', 'Prédio Inteiro', 
                      'Loja/Salão', 'Galpão/Depósito/Armazém', 
                      'Casa Comercial','Terreno Padrão', 'Box/Garagem', 
                      'Loja Shopping/ Ct Comercial', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
dados.query('@imoveis_comerciais in Tipo') # somente os comerciais
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
dados.query('@imoveis_comerciais not in Tipo') # sem os imóveis comerciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
df_nao_comerciais = dados.query('@imoveis_comerciais not in Tipo')
df_nao_comerciais.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
df_nao_comerciais.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_preco_tipo = df_nao_comerciais.groupby('Tipo')[['Valor']].mean().sort_values(by='Valor', ascending=False)
df_preco_tipo
# df_preco_tipo.plot(kind='barh', figsize=(12,8), color = 'blue')
# Out:
#                            Valor
# Tipo
# Casa de Condomínio  11952.061245
# Casa                 6793.454922
# Apartamento          4744.614648
# Flat                 4546.189076
# Loft                 2557.882353
# Studio               2400.000000
# Casa de Vila         1574.369478
# Quitinete            1246.840909

# %% [markdown]
# Qual o percentual de cada tipo de imóvel na BD?

# %%
df_nao_comerciais['Tipo'].value_counts(normalize=True)
# Out:
# Tipo
# Apartamento           0.845139
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Quitinete             0.036173
# Flat                  0.020596
# Casa de Vila          0.010774
# Loft                  0.002207
# Studio                0.000173
# Name: proportion, dtype: float64

# %%
df_nao_comerciais.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo')
# Out:
#                     proportion
# Tipo
# Apartamento           0.845139
# Casa                  0.041842
# Casa de Condomínio    0.043096
# Casa de Vila          0.010774
# Flat                  0.020596
# Loft                  0.002207
# Quitinete             0.036173
# Studio                0.000173

# %%
df_percentual_tipo = df_nao_comerciais.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo')

df_percentual_tipo.plot(kind='bar', figsize=(12,8), color = 'red', xlabel='Tipos', ylabel='Percentual')
# Out:
# <Axes: xlabel='Tipos', ylabel='Percentual'>

# %% [markdown]
# Selecionando apenas imóveis do tipo Apartamento dado que representa aproximadamente 85% do imóveis não comerciais.

# %%
df_nao_comerciais.query('Tipo == "Apartamento"')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
df_tipo_apartamento = df_nao_comerciais.query('Tipo == "Apartamento"')
df_tipo_apartamento.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# # Outras demandas do time ML

# %% [markdown]
# Calcular média dos quartos por apartamento

# %%
media_apartamento = df_tipo_apartamento['Valor'].mean()
print('Média dos quartos por Apartamento = R$ %.2f' % media_apartamento)
# Out:
# Média dos quartos por Apartamento = R$ 4744.61

# %% [markdown]
# Conferir quantos bairros únicos existem na nossa base de dados

# %%
bairros = df_tipo_apartamento['Bairro'].nunique()
print('Qtd de bairros para aluguel são = %.f' % bairros)
# Out:
# Qtd de bairros para aluguel são = 149

# %% [markdown]
# Analisar quais bairros possuem a média de valor de aluguel mais elevadas

# %%
df_media_bairros = df_tipo_apartamento.groupby('Bairro')[['Valor']].mean().sort_values(by='Valor', ascending=False)
df_media_bairros.head()
# Out:
#                       Valor
# Bairro
# Joá            15500.000000
# Arpoador       12429.769231
# Cidade Jardim  12000.000000
# Ipanema         9487.205317
# Botafogo        9369.207116

# %%
df_media_bairros.head(5).plot(kind='barh')
# Out:
# <Axes: ylabel='Bairro'>

# %% [markdown]
# # Tratando dados nulos

# %%
df_tipo_apartamento.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# 5      False   False    False  False   False  False  False        True   True
# 6      False   False    False  False   False  False  False       False  False
# 10     False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32951  False   False    False  False   False  False  False       False   True
# 32953  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
#
# [19532 rows x 9 columns]

# %%
df_tipo_apartamento.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %% [markdown]
# Nesse caso específico iremos atribuir o valor 0 ('zero') para os valores nulos, nem sempre o projeto permitirá esse tipo de ajuste.
# Por vezes poderemos substituir por exemplo pela média da coluna, 'dropar' somentes os valores nulos, ou até mesmo "dropar" a coluna inteira.

# %%
df_tipo_apartamento = df_tipo_apartamento.fillna(0)
df_tipo_apartamento
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   0.0
# ...

# %%
df_tipo_apartamento.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# # Remoção de resgistros inconsistentes

# %% [markdown]
# Remover onde Valor = 0

# %%
df_tipo_apartamento.query('Valor != 0', inplace=True)

# %% [markdown]
# Remover onde Condomínio = 0

# %%
df_tipo_apartamento.query('Condominio != 0', inplace=)
# Out:
#   Cell In[386], line 1
#     df_tipo_apartamento.query('Condominio != 0', inplace=)
#                                                          ^
# SyntaxError: invalid syntax

# %%
print(
    f'Há "{df_tipo_apartamento.query("Valor == 0 & Condominio == 0").value_counts().sum()}" linhas com valor "Zero" em Valor e Condominio'
)
# Out:
# Há "0" linhas com valor "Zero" em Valor e Condominio

# %% [markdown]
# Como na nossa tabela estamos trabalhando apenas com imóveis do Tipo Apartamento poderemos remover também essa coluna.

# %%
df_tipo_apartamento.Tipo.unique()
# Out:
# array(['Apartamento'], dtype=object)

# %%
df_tipo_apartamento.drop(columns='Tipo', axis=1, inplace=True)

# %%
df_tipo_apartamento.head()
# Out:
#           Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  IPTU
# 3         Centro        1      0       0    15   800.0       390.0  20.0
# 4   Higienópolis        1      0       0    48   800.0       230.0   0.0
# 5   Vista Alegre        3      1       0    70  1200.0         0.0   0.0
# 6       Cachambi        2      0       0    50  1300.0       301.0  17.0
# 10        Centro        1      0       0    36  1200.0         0.0   0.0

# %% [markdown]
# # Aplicando filtros

# %% [markdown]
# FIltro 1: Apartamentos com Quarto = 1 e Valor <= R$ 1200.

# %%
df_filtro_1 = df_tipo_apartamento.query('Quartos == 1 & Valor < 1200')

# %%
df_filtro_1
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32596        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 32617     Pechincha        1      0       1    69   900.0       640.0  126.0
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %%
    # Outra forma de filtrar seria:
#df_tipo_apartamento['Quartos'] == 1 >- retorna valores booleanos
    # coloca numa variável
#selecao1 = (df_tipo_apartamento['Quartos'] == 1) & (df_tipo_apartamento['Valor'] < 1200)
    # ao colocar como um dataframe automaticamente os valores "false" não são considerados
    # repetimos esse procedimento para o outro filtro

# %% [markdown]
# FIltro 2: Apartamentos com Quarto >= 2, Valor < R$ 3000 e Área > 70 m².

# %%
df_filtro_2 = df_tipo_apartamento.query('Quartos >= 2 & Valor < 3000 & Area > 70')

# %%
df_filtro_2
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 12          Lins de Vasconcelos        3      1       1    90  1500.0
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 36     Recreio dos Bandeirantes        3      1       1   105  2300.0
# ...                         ...      ...    ...     ...   ...     ...
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
# 32941           Barra da Tijuca        3      2       0    98  2300.0
# 32944  Recreio dos Bandeirantes        3      2       1    88  1550.0
# 32956               Jacarepaguá        3      1       2    78  1800.0
#
#        Condominio   IPTU
# 12          455.0   14.0
# 21          700.0  138.0
# 24          700.0    0.0
# ...

# %% [markdown]
# # Salvando o dataframe como formato .cvs

# %%
df_tipo_apartamento.to_csv('dados_apartamentos.csv', index=False, sep=';')
# salvo da maneira que recebemos, com separador ';'

# %%
pd.read_csv('dados_apartamentos.csv')
# Out:
#       Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0                       Centro;1;0;0;15;800.0;390.0;20.0
# 1                  Higienópolis;1;0;0;48;800.0;230.0;0.0
# 2                    Cachambi;2;0;0;50;1300.0;301.0;17.0
# 3                      Grajaú;2;1;0;70;1500.0;642.0;74.0
# 4         Lins de Vasconcelos;3;1;1;90;1500.0;455.0;14.0
# ...                                                  ...
# 18775           Vila Valqueire;2;0;0;52;1000.0;550.0;0.0
# 18776                    Méier;2;0;0;70;900.0;490.0;48.0
# 18777             Jacarepaguá;3;1;2;78;1800.0;800.0;40.0
# 18778    São Francisco Xavier;2;1;0;48;1400.0;509.0;37.0
# 18779                   Leblon;2;0;0;70;3000.0;760.0;0.0
#
# [18780 rows x 1 columns]

# %%
df_filtro_1.to_csv('dados_filtro_1.csv', index=False, sep=';')
df_filtro_2.to_csv('dados_filtro_2.csv', index=False, sep=';')

# %%
pd.read_csv('dados_filtro_1.csv')
# pd.read_csv('dados_filtro_2.csv')
# Out:
#     Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0                     Centro;1;0;0;15;800.0;390.0;20.0
# 1                Higienópolis;1;0;0;48;800.0;230.0;0.0
# 2                     Tijuca;1;0;0;48;750.0;772.0;25.0
# 3                     Centro;1;0;0;27;750.0;371.0;19.0
# 4                   Centro;1;1;0;37;1100.0;540.0;900.0
# ..                                                 ...
# 494                   Grajaú;1;0;1;37;1000.0;200.0;0.0
# 495               Pechincha;1;0;1;69;900.0;640.0;126.0
# 496                  Glória;1;0;0;46;1100.0;453.0;32.0
# 497                Botafogo;1;0;0;21;1000.0;282.0;25.0
# 498                  Tijuca;1;0;0;28;1000.0;360.0;25.0
#
# [499 rows x 1 columns]

# %% [markdown]
# # Demandas time DEV

# %% [markdown]
# Acrescentar colunas com valores sumarizados.
# Para isso iremos carregar os dados iniciais.

# %% [markdown]
# valor_por_mes: essa coluna deve conter os gastos mensais de cada imóvel, incluindo aluguel e condomínio;

# %%
dados = pd.read_csv('aluguel.csv', sep=';')
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
# poderíamos fazer pelo médtodo assign que ficaria assim:
# dados = dados.assign(
#             valor_por_mes=dados['Valor'] + dados['Condominio'])

# uma forma mais simplificada é:
dados['Valor_por_mes'] = dados['Valor'] + dados['Condominio']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes
# 0  1700.0       500.0    60.0         2200.0
# 1  7000.0         NaN     NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0
# 3   800.0       390.0    20.0         1190.0
# 4   800.0       230.0     NaN         1030.0

# %% [markdown]
# valor_por_ano: essa coluna deve conter os gastos anuais por imóvel, ou seja, IPTU mais 12 meses de aluguel e condomínio

# %%
# dados = dados.assign(valor_por_ano= (12 * dados['valor_por_mes']) + dados['IPTU'])
dados['Valor_por_ano'] = dados['Valor_por_mes'] * 12 + dados['IPTU']

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN

# %% [markdown]
# Adicionar mais duas colunas a nossa tabela.

# %% [markdown]
# Coluna: Descrição (essa coluna deve possuir uma sumarização das principais informações dos imóveis que serão apresentadas no site: tipo de imóvel, bairro, quantidade de quartos e vagas de garagem)

# %%
dados['Descricao'] = dados['Tipo'] + ' em ' + dados['Bairro'] + ' com ' + \
                    dados['Quartos'].astype(str) + ' quarto(s) ' + 'e' + \
                   ' com ' + dados['Vagas'].astype(str) + ' vaga(s) de garagem.'

dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descrição  \
# 0  Tipo: 0                      Quitinete\n1     ...
# ...

# %% [markdown]
# Coluna: Possi_suite (essa coluna deve informar se o imóvel possui ou não suítes, sem se importar com a quantidade.)q

# %%
dados['Possui_suite'] = dados['Suites'].apply(lambda x: "Sim" if x > 0 else "Não")
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descrição  \
# 0  Tipo: 0                      Quitinete\n1     ...
# ...

# %%
dados.to_csv('dados_completos_dev.csv', sep=';', index=False)

# %%
pd.read_csv('dados_completos_dev.csv', sep=';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...
